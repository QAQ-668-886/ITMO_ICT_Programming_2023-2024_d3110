# %% [markdown]
# lab2（Реализовать шифрование шифрами Цезаря и Вижинера.）

# %%
# Шифрование Цезаря
def caesar_encrypt(text, shift):
    encrypted_text = ""
    for char in text:
        if char.isalpha():
            # Определить случай
            ascii_offset = ord('A') if char.isupper() else ord('a')
            encrypted_char = chr((ord(char) - ascii_offset + shift) % 26 + ascii_offset)
            encrypted_text += encrypted_char
        else:
            encrypted_text += char
    return encrypted_text

# Шифрование по методу Виженера
def vigenere_encrypt(text, key):
    encrypted_text = ""
    key_length = len(key)
    for i, char in enumerate(text):
        if char.isalpha():
            # Определить случай
            ascii_offset = ord('A') if char.isupper() else ord('a')
            key_char = key[i % key_length]
            key_offset = ord(key_char.upper()) - ord('A')
            encrypted_char = chr((ord(char) - ascii_offset + key_offset) % 26 + ascii_offset)
            encrypted_text += encrypted_char
        else:
            encrypted_text += char
    return encrypted_text

# Расшифровка шифра Цезаря
def caesar_decrypt(text, shift):
    return caesar_encrypt(text, -shift)

# Расшифровка шифра Виженера
def vigenere_decrypt(text, key):
    decrypted_text = ""
    key_length = len(key)
    for i, char in enumerate(text):
        if char.isalpha():
            # Определить случай
            ascii_offset = ord('A') if char.isupper() else ord('a')
            key_char = key[i % key_length]
            key_offset = ord(key_char.upper()) - ord('A')
            decrypted_char = chr((ord(char) - ascii_offset - key_offset) % 26 + ascii_offset)
            decrypted_text += decrypted_char
        else:
            decrypted_text += char
    return decrypted_text

# Демонстрация основной функции
def main():
    name = "Tian kunlong"  # Заменить на свое имя
    caesar_shift = 3  # смещение шифра Цезаря
    vigenere_key = "KEY"  # ключ шифра Виженера

    # Шифрование с использованием шифра Цезаря
    caesar_encrypted = caesar_encrypt(name, caesar_shift)
    print(f"Результаты шифра Цезаря: {caesar_encrypted}")

    # Расшифровка с использованием шифра Цезаря
    caesar_decrypted = caesar_decrypt(caesar_encrypted, caesar_shift)
    print(f"Результаты расшифровки Цезаря: {caesar_decrypted}")

    # Зашифровано с использованием шифра Виженера
    vigenere_encrypted = vigenere_encrypt(name, vigenere_key)
    print(f"\nРезультаты шифра Вирджинии: {vigenere_encrypted}")

    # Результаты расшифровки Вирджинии
    vigenere_decrypted = vigenere_decrypt(vigenere_encrypted, vigenere_key)
    print(f"Результаты расшифровки Вирджинии: {vigenere_decrypted}")

if __name__ == "__main__":
    main()
# Out:
# Результаты шифра Цезаря: Wldq nxqorqj
# Результаты расшифровки Цезаря: Tian kunlong
#
# Результаты шифра Вирджинии: Dmyx ierjyre
# Результаты расшифровки Вирджинии: Tian kunlong

# %% [markdown]
# ### 代码分析与用途说明
# #### 1. **`caesar_encrypt` 函数**
# **用途**: 使用凯撒密码对文本进行加密。
# - **逻辑**:
#   - 遍历输入的每个字符。
#   - 如果是字母，根据其大小写确定基准偏移量（大写字母用 `A`，小写字母用 `a`）。
#   - 应用偏移量将字母在字母表中向后移动指定的位数。
#   - 非字母字符保持不变。
# - **代码选择原因**:
#   - 凯撒密码是简单的替换加密技术，易于实现和理解。
#   - 通过循环移位实现加密，适合初学者理解基本加密原理。
#
# #### 2. **`vigenere_encrypt` 函数**
# **用途**: 使用维吉尼亚密码对文本进行加密。
# - **逻辑**:
#   - 使用密钥来决定每个字符的偏移量。
#   - 密钥长度不足时循环使用。
#   - 对每个字母应用对应的密钥偏移量。
# - **代码选择原因**:
#   - 维吉尼亚密码比凯撒密码更安全，因为它使用了可变的偏移量。
#   - 密钥的使用增加了加密的复杂度，提升了安全性。
#
# #### 3. **`caesar_decrypt` 函数**
# **用途**: 解密通过凯撒密码加密的文本。
# - **逻辑**:
#   - 实际上是`caesar_encrypt`的逆向操作。
#   - 通过负的偏移量将字母在字母表中向前移动，恢复原始文本。
# - **代码选择原因**:
#   - 凯撒加密和解密是对称的，只需改变偏移量的方向即可实现解密。
#
# #### 4. **`vigenere_decrypt` 函数**
# **用途**: 解密通过维吉尼亚密码加密的文本。
# - **逻辑**:
#   - 使用相同的密钥，通过逆向偏移来还原每个字符。
#   - 密钥循环使用，确保与加密过程一致。
# - **代码选择原因**:
#   - 维吉尼亚加密和解密需要相同的密钥，保持加密和解密的一致性。
#
# #### 5. **`main` 函数**
# **用途**: 演示加密和解密的全过程。
# - **逻辑**:
#   - 定义一个示例名字（可替换为实际名字）。
#   - 设置凯撒密码的偏移量和维吉尼亚密码的密钥。
#   - 分别演示凯撒和维吉尼亚加密及其对应的解密过程。
# - **代码选择原因**:
#   - 提供一个完整的使用示例，便于理解和验证加密解密流程。
#   - 展示如何在实际应用中使用这些加密函数。
#
# ### 总结
# 这些代码通过实现两种经典的加密算法，帮助理解基本的加密解密原理。凯撒密码简单直观，适合作为入门示例；维吉尼亚密码则展示了如何通过引入密钥来增强安全性。通过主函数的演示，用户可以轻松看到加密和解密的完整过程，验证算法的正确性。

# %% [markdown]
# lab3 Реализовать решатель Судоку.

# %%
def solve_sudoku(board):
    """
    Основная функция решения судоку.
    Использует алгоритм обратногоPropagation, пытаясь заполнить цифры и проверяя соответствие правилам.

    Параметр:
    board -- двумерный список 9x9, представляющий поле судоку, пустые ячейки обозначены 0

    Возвращает:
    True если судоку имеет решение, False если нет
    """
    # Найти первую пустую ячейку на поле
    empty = find_empty(board)
    if not empty:
        return True  # Если пустых ячеек нет, судоку решено

    row, col = empty

    # Попытаться заполнить цифрами от 1 до 9
    for num in range(1, 10):
        # Проверить, может ли цифра быть в этой позиции
        if is_valid(board, row, col, num):
            # Если может, заполнить ячейку
            board[row][col] = num

            # Рекурсивно попытаться заполнить следующую пустую ячейку
            if solve_sudoku(board):
                return True

            # Если рекурсивный вызов возвращает False, значит эта цифра не подходит, откатываем и пробуем следующую
            board[row][col] = 0

    # Если ни одна из цифр 1-9 не подходит, судоку не имеет решения
    return False

def find_empty(board):
    """
    Найти первую пустую ячейку (значение 0) на поле

    Параметр:
    board -- поле судоку

    Возвращает:
    (row, col) координаты пустой ячейки, если пустых ячеек нет, возвращает None
    """
    for row in range(9):
        for col in range(9):
            if board[row][col] == 0:
                return (row, col)
    return None

def is_valid(board, row, col, num):
    """
    Проверить, может ли цифра быть в указанной позиции

    Параметры:
    board -- поле судоку
    row -- номер строки (0-8)
    col -- номер столбца (0-8)
    num -- проверяемая цифра (1-9)

    Возвращает:
    True если цифра может быть в этой позиции, False иначе
    """
    # Проверка строки
    for x in range(9):
        if board[row][x] == num:
            return False

    # Проверка столбца
    for x in range(9):
        if board[x][col] == num:
            return False

    # Проверка 3x3 блока
    # Определение начала блока
    start_row = (row // 3) * 3
    start_col = (col // 3) * 3

    for i in range(3):
        for j in range(3):
            if board[start_row + i][start_col + j] == num:
                return False

    return True

# Пример поля судоку
example_board = [
    [5, 3, 0, 0, 7, 0, 0, 0, 0],
    [6, 0, 0, 1, 9, 5, 0, 0, 0],
    [0, 9, 8, 0, 0, 0, 0, 6, 0],
    [8, 0, 0, 0, 6, 0, 0, 0, 3],
    [4, 0, 0, 8, 0, 3, 0, 0, 1],
    [7, 0, 0, 0, 2, 0, 0, 0, 6],
    [0, 6, 0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 4, 1, 9, 0, 0, 5],
    [0, 0, 0, 0, 8, 0, 0, 7, 9]
]

# Решение примера судоку
if solve_sudoku(example_board):
    print("Судоку решено:")
    for row in example_board:
        print(row)
else:
    print("Судоку не имеет решения")
# Out:
# Судоку решено:
# [5, 3, 4, 6, 7, 8, 9, 1, 2]
# [6, 7, 2, 1, 9, 5, 3, 4, 8]
# [1, 9, 8, 3, 4, 2, 5, 6, 7]
# [8, 5, 9, 7, 6, 1, 4, 2, 3]
# [4, 2, 6, 8, 5, 3, 7, 9, 1]
# [7, 1, 3, 9, 2, 4, 8, 5, 6]
# [9, 6, 1, 5, 3, 7, 2, 8, 4]
# [2, 8, 7, 4, 1, 9, 6, 3, 5]
# [3, 4, 5, 2, 8, 6, 1, 7, 9]

# %% [markdown]
# 以下是一个数独解算器的Python实现，使用回溯算法来解决数独问题。
#
# ```python
# def solve_sudoku(board):
#     """
#     解决数独问题的主函数。
#     使用回溯算法，尝试填入数字并检查是否符合规则。
#
#     参数:
#     board -- 一个9x9的二维列表，表示数独棋盘，空格用0表示
#
#     返回:
#     True 如果数独有解，False 如果无解
#     """
#     # 找到棋盘上第一个空格
#     empty = find_empty(board)
#     if not empty:
#         return True  # 如果没有空格，则数独已解决
#
#     row, col = empty
#
#     # 尝试填入1到9
#     for num in range(1, 10):
#         # 检查填入的数字是否有效
#         if is_valid(board, row, col, num):
#             # 如果有效，填入数字
#             board[row][col] = num
#
#             # 递归尝试填入下一个空格
#             if solve_sudoku(board):
#                 return True
#
#             # 如果递归调用返回False，说明这个数字不行，回溯并尝试下一个数字
#             board[row][col] = 0
#
#     # 如果1-9都不行，则数独无解
#     return False
#
# def find_empty(board):
#     """
#     找到棋盘上的第一个空格（值为0的位置）
#
#     参数:
#     board -- 数独棋盘
#
#     返回:
#     (row, col) 表示空格的位置，如果没有空格则返回None
#     """
#     for row in range(9):
#         for col in range(9):
#             if board[row][col] == 0:
#                 return (row, col)
#     return None
#
# def is_valid(board, row, col, num):
#     """
#     检查在指定位置填入指定数字是否有效
#
#     参数:
#     board -- 数独棋盘
#     row -- 行号（0-8）
#     col -- 列号（0-8）
#     num -- 要验证的数字（1-9）
#
#     返回:
#     True 如果有效，False 否则
#     """
#     # 检查行
#     for x in range(9):
#         if board[row][x] == num:
#             return False
#
#     # 检查列
#     for x in range(9):
#         if board[x][col] == num:
#             return False
#
#     # 检查3x3宫格
#     # 确定宫格的起始位置
#     start_row = (row // 3) * 3
#     start_col = (col // 3) * 3
#
#     for i in range(3):
#         for j in range(3):
#             if board[start_row + i][start_col + j] == num:
#                 return False
#
#     return True
#
# # 示例数独棋盘
# example_board = [
#     [5, 3, 0, 0, 7, 0, 0, 0, 0],
#     [6, 0, 0, 1, 9, 5, 0, 0, 0],
#     [0, 9, 8, 0, 0, 0, 0, 6, 0],
#     [8, 0, 0, 0, 6, 0, 0, 0, 3],
#     [4, 0, 0, 8, 0, 3, 0, 0, 1],
#     [7, 0, 0, 0, 2, 0, 0, 0, 6],
#     [0, 6, 0, 0, 0, 0, 2, 8, 0],
#     [0, 0, 0, 4, 1, 9, 0, 0, 5],
#     [0, 0, 0, 0, 8, 0, 0, 7, 9]
# ]
#
# # 解决示例数独
# if solve_sudoku(example_board):
#     print("数独有解:")
#     for row in example_board:
#         print(row)
# else:
#     print("数独无解")
# ```
#
# ### 代码说明：
#
# 1. `solve_sudoku(board)` 是主函数，使用回溯算法解决数独问题：
#    - 找到棋盘上的第一个空格
#    - 尝试填入1到9的数字
#    - 检查填入的数字是否有效
#    - 如果有效，递归调用自身尝试填入下一个空格
#    - 如果递归调用失败，回溯并尝试下一个数字
#
# 2. `find_empty(board)` 函数用于找到棋盘上的第一个空格（值为0的位置）。
#
# 3. `is_valid(board, row, col, num)` 函数用于检查在指定位置填入指定数字是否有效：
#    - 检查行是否已经存在相同的数字
#    - 检查列是否已经存在相同的数字
#    - 检查3x3宫格是否已经存在相同的数字
#
# ### 为什么这样设计：
#
# 1. 使用回溯算法是因为数独问题是一个典型的约束满足问题（CSP），回溯是解决这类问题的有效方法。
#
# 2. 将代码分为多个函数（`solve_sudoku`、`find_empty`、`is_valid`）可以使代码结构更清晰，便于维护和理解。
#
# 3. 在`is_valid`函数中同时检查行、列和宫格，是因为数独的规则要求这三者都不能重复。
#
# 4. 使用递归实现回溯，因为数独的解决过程需要不断尝试和回溯，递归是实现这种过程的自然方式。
#
# 这个实现可以解决任何有效的数独问题，并且由于使用了回溯算法，可以处理所有可能的数独情况，无论是简单还是困难的数独。

# %% [markdown]
# lab4Реализовать игру "Жизнь".

# %%
import random

def get_neighbors(grid, x, y):
    """
    Получает количество живых соседей клетки.
    """
    count = 0
    for i in range(-1, 2):
        for j in range(-1, 2):
            if i == 0 and j == 0:
                continue
            if x + i < 0 or x + i >= len(grid) or y + j < 0 or y + j >= len(grid[0]):
                continue
            if grid[x + i][y + j]:
                count += 1
    return count

def next_generation(grid):
    """
    Определяет следующее поколение клеток.
    """
    new_grid = []
    for i in range(len(grid)):
        new_grid.append([])
        for j in range(len(grid[0])):
            neighbors = get_neighbors(grid, i, j)
            if grid[i][j]: # Живая клетка
                if neighbors < 2 or neighbors > 3:
                    new_grid[i].append(False)  # Умирает
                else:
                    new_grid[i].append(True)  # Выживает
            else: # Мёртвая клетка
                if neighbors == 3:
                    new_grid[i].append(True)  # Рождается
                else:
                    new_grid[i].append(False)  # Остается мёртвой
    return new_grid

def display_grid(grid):
    """
    Выводит сетку клеток на экран.
    """
    for row in grid:
        for cell in row:
            print("X" if cell else ".", end=" ")
        print()

# Пример начальной конфигурации
initial_grid = [
    [False, False, False, False, False],
    [False, True, True, False, False],
    [False, True, True, False, False],
    [False, False, False, False, False],
    [False, False, False, False, False]
]

# Выводим начальную сетку
print("Начальное состояние:")
display_grid(initial_grid)

# Запускаем игру на несколько поколений
num_generations = 5
current_grid = initial_grid
for generation in range(num_generations):
    current_grid = next_generation(current_grid)
    print(f"\nПоколение {generation + 1}:")
    display_grid(current_grid)
# Out:
# Начальное состояние:
# . . . . .
# . X X . .
# . X X . .
# . . . . .
# . . . . .
#
# Поколение 1:
# . . . . .
# . X X . .
# . X X . .
# . . . . .
# . . . . .
#
# Поколение 2:
# . . . . .
# . X X . .
# . X X . .
# . . . . .
# . . . . .
#
# Поколение 3:
# . . . . .
# . X X . .
# . X X . .
# . . . . .
# . . . . .
#
# Поколение 4:
# . . . . .
# . X X . .
# . X X . .
# . . . . .
# . . . . .
#
# Поколение 5:
# . . . . .
# . X X . .
# . X X . .
# . . . . .
# . . . . .

# %% [markdown]
# 说明：
# get_neighbors(grid, x, y)：用于计算坐标处细胞存活邻居数量的函数(x, y)。
#
# next_generation(grid)：应用生命游戏规则来确定下一代细胞的功能。
#
# display_grid(grid)：将单元格网格打印到屏幕上的函数，其中“X”表示活单元格，“。” - 死亡细胞。
#
# initial_grid：初始网格配置的示例。
#
# 核心代码模拟了多代生命游戏，显示了每个新状态。
